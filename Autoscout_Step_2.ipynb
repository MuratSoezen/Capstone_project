# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
df1=pd.read_csv('Autoscout24_Step_1_1.csv')

# %%
df1
# Out:
#        Unnamed: 0              make_model           make  \
# 0               0     Mercedes-Benz A 160  Mercedes-Benz
# 1               1   Mercedes-Benz EQE 350  Mercedes-Benz
# 2               2  Mercedes-Benz A 45 AMG  Mercedes-Benz
# 3               3  Mercedes-Benz A 35 AMG  Mercedes-Benz
# 4               4  Mercedes-Benz A 45 AMG  Mercedes-Benz
# ...           ...                     ...            ...
# 28625       28625               Volvo S90          Volvo
# 28626       28626               Volvo S40          Volvo
# 28627       28627               Volvo C30          Volvo
# 28628       28628               Volvo S90          Volvo
# 28629       28629               Volvo S80          Volvo
#
#                                                 location  price  body_type  \
# 0      P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  16950   Compact
# 1           APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  80900   Compact
# ...

# %%
df1=df1.drop('Unnamed: 0',axis=1)

# %%
df1
# Out:
#                    make_model           make  \
# 0         Mercedes-Benz A 160  Mercedes-Benz
# 1       Mercedes-Benz EQE 350  Mercedes-Benz
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz
# ...                       ...            ...
# 28625               Volvo S90          Volvo
# 28626               Volvo S40          Volvo
# 28627               Volvo C30          Volvo
# 28628               Volvo S90          Volvo
# 28629               Volvo S80          Volvo
#
#                                                 location  price  body_type  \
# 0      P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  16950   Compact
# 1           APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  80900   Compact
# 2      PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...  69900   Compact
# 3      Carrer de Provença, 31 Local,  8029 BARCELONA, ES  46990   Compact
# ...

# %%
df1.isnull().sum()
# Out:
# make_model                  0
# make                        0
# location                    0
# price                       0
# body_type                   0
# type                        0
# doors                     359
# warranty                12846
# mileage                     1
# Gearbox                   248
# fuel_type                1787
# seller                      0
# seats                    3125
# engine_size_cc           1403
# gears                    9676
# co_emission             10036
# drivetrain              11737
# cylinders                9778
# comfort_convenience      3197
# entertainment_media      4986
# safety_security          3215
# numbers_extras           5150
# empty_weight            10872
# full_service_history    16065
# non-smoker              17036
# emission_class          10771
# upholstery              10020
# previous_owner          14615
# other_fuel              26317
# power_consumption       28115
# energy_efficiency       20826
# ...

# %%
df1.location
# Out:
# 0        P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# 1             APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# 2        PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# 3        Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# 4                   CARRIL ARAGONES 4,  30007 CASILLAS, ES
#                                ...
# 28625             HERMANOS LUMIERE Nº16,  29004 MALAGA, ES
# 28626                    Stobbeweg 6,  2461 EX TER AAR, NL
# 28627               Sur rendez-vous,  5060 Sambreville, BE
# 28628      Bergambachterstraat 5,  2871 JB SCHOONHOVEN, NL
# 28629                    Lage Ham 106,  5102 AE DONGEN, NL
# Name: location, Length: 28630, dtype: object

# %%
# as location only countries
df1['location'] = df1['location'].str.split(',').str[-1].str.strip()

# %%
df1['fuel_type'].isnull().sum()
# Out:
# 1787

# %%
#fuel_type is very important for the price, thatswhy i drop nan values
df1.dropna(subset=['fuel_type'], inplace=True)

# %%
df1.shape[0]
# Out:
# 26843

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1['price']=df1['price'].astype(float)

# %%
df1.location.isnull().sum()
# Out:
# 0

# %%
df1.type.isnull().sum()
# Out:
# 0

# %%
df1.sample()
# Out:
#        make_model   make location    price           body_type    type  doors  \
# 25461  Volvo XC90  Volvo       DE  78490.0   Off-Road/Pick-up    Used     5.0
#
#       warranty  mileage    Gearbox fuel_type  seller  seats  engine_size_cc  \
# 25461      NaN  11731.0  Automatic   Benzine  Dealer    7.0          1969.0
#
#        gears co_emission drivetrain  cylinders  \
# 25461    8.0          47       4WD         4.0
#
#                                      comfort_convenience  \
# 25461  Air conditioning, Armrest, Automatic climate c...
#
#                                      entertainment_media  \
# 25461  Android Auto, Apple CarPlay, Bluetooth, Digita...
#
#                                          safety_security  \
# 25461  ABS, Adaptive Cruise Control, Adaptive headlig...
#
#                                           numbers_extras  empty_weight  \
# 25461  Alloy wheels, Catalytic Converter, Roof rack, ...        2328.0
#
# ...

# %%
df1.body_type.value_counts()
# Out:
#  Station wagon        5104
#  Compact              4990
#  Off-Road/Pick-up     4920
#  Sedan                4593
#  Coupe                3967
#  Convertible          3269
# Name: body_type, dtype: int64

# %%
df1.isnull().sum()
# Out:
# make_model                  0
# make                        0
# location                    0
# price                       0
# body_type                   0
# type                        0
# doors                     332
# warranty                12214
# mileage                     0
# Gearbox                   238
# fuel_type                   0
# seller                      0
# seats                    3003
# engine_size_cc           1024
# gears                    8915
# co_emission              9163
# drivetrain              11074
# cylinders                8956
# comfort_convenience      3059
# entertainment_media      4784
# safety_security          3082
# numbers_extras           4943
# empty_weight            10238
# full_service_history    15242
# non-smoker              16060
# emission_class          10056
# upholstery               9582
# previous_owner          13818
# other_fuel              26307
# power_consumption       26723
# energy_efficiency       19746
# ...

# %%
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26838    False
# 26839    False
# 26840    False
# 26841    False
# 26842    False
# Name: doors, Length: 26843, dtype: bool

# %%
nan_doors = df1[df1['doors'].isna()]

# %%
nan_doors['make_model'].unique()
# Out:
# array(['Mercedes-Benz SL 560', 'Mercedes-Benz 190',
#        'Mercedes-Benz SL 450', 'Mercedes-Benz 280', 'Mercedes-Benz E 200',
#        'Mercedes-Benz Sprinter', 'Mercedes-Benz E 220',
#        'Mercedes-Benz 260', 'Opel Adam', 'Opel Astra', 'Opel Cascada',
#        'Opel Manta', 'Opel Rekord', 'Opel Calibra', 'Opel Kadett',
#        'Opel GT', 'Opel Commodore', 'Opel Corsa', 'Opel Grandland X',
#        'Opel Insignia', 'Renault Clio', 'Renault Twizy',
#        'Renault Alpine A110', 'Renault R 4', 'Renault Talisman',
#        'Renault Kangoo', 'Renault Megane', 'Renault Alpine A310',
#        'Renault Alpine V6', 'Renault Arkana', 'Renault Laguna',
#        'Renault Kadjar', 'Renault Captur', 'Renault Alaskan',
#        'Renault Master', 'Peugeot 307', 'Peugeot 1007', 'Peugeot 308',
#        'Peugeot Expert', 'Peugeot 504', 'Peugeot ', 'Peugeot 207',
#        'Peugeot 206', 'Peugeot 407', 'Peugeot 309', 'Peugeot RCZ',
# ...

# %%
df1[df1['make_model']=='Volvo C30']
# Out:
#       make_model   make location    price  body_type    type  doors  \
# 23444  Volvo C30  Volvo       NL   3550.0   Compact    Used     3.0
# 23453  Volvo C30  Volvo       NL   5950.0   Compact    Used     3.0
# 23459  Volvo C30  Volvo       NL  13940.0   Compact    Used     3.0
# 23468  Volvo C30  Volvo       NL  29900.0   Compact    Used     3.0
# 23476  Volvo C30  Volvo       DE   5999.0   Compact    Used     2.0
# ...          ...    ...      ...      ...        ...     ...    ...
# 25180  Volvo C30  Volvo       NL   4495.0     Coupe    Used     2.0
# 25182  Volvo C30  Volvo       IT   8500.0     Coupe    Used     3.0
# 26788  Volvo C30  Volvo       IT   4500.0     Sedan    Used     3.0
# 26818  Volvo C30  Volvo       DE   5500.0     Sedan    Used     3.0
# 26840  Volvo C30  Volvo       BE   7300.0     Sedan    Used     3.0
#
#           warranty   mileage    Gearbox fuel_type          seller  seats  \
# 23444          NaN  276358.0     Manual    Diesel          Dealer    4.0
# ...

# %%
df1.isnull().any()
# Out:
# make_model              False
# make                    False
# location                False
# price                   False
# body_type               False
# type                    False
# doors                    True
# warranty                 True
# mileage                 False
# Gearbox                  True
# fuel_type               False
# seller                  False
# seats                    True
# engine_size_cc           True
# gears                    True
# co_emission              True
# drivetrain               True
# cylinders                True
# comfort_convenience      True
# entertainment_media      True
# safety_security          True
# numbers_extras           True
# empty_weight             True
# full_service_history     True
# non-smoker               True
# emission_class           True
# upholstery               True
# previous_owner           True
# other_fuel               True
# power_consumption        True
# energy_efficiency        True
# ...

# %%
round(df1.isnull().sum()/len(df1)*100,2)
# Out:
# make_model               0.00
# make                     0.00
# location                 0.00
# price                    0.00
# body_type                0.00
# type                     0.00
# doors                    1.24
# warranty                45.50
# mileage                  0.00
# Gearbox                  0.89
# fuel_type                0.00
# seller                   0.00
# seats                   11.19
# engine_size_cc           3.81
# gears                   33.21
# co_emission             34.14
# drivetrain              41.25
# cylinders               33.36
# comfort_convenience     11.40
# entertainment_media     17.82
# safety_security         11.48
# numbers_extras          18.41
# empty_weight            38.14
# full_service_history    56.78
# non-smoker              59.83
# emission_class          37.46
# upholstery              35.70
# previous_owner          51.48
# other_fuel              98.00
# power_consumption       99.55
# energy_efficiency       73.56
# ...

# %%
df1=df1.drop('battery_ownership',axis=1)

# %%
df1[~df1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [make_model, make, location, price, body_type, type, doors, warranty, mileage, Gearbox, fuel_type, seller, seats, engine_size_cc, gears, co_emission, drivetrain, cylinders, comfort_convenience, entertainment_media, safety_security, numbers_extras, empty_weight, full_service_history, non-smoker, emission_class, upholstery, previous_owner, other_fuel, power_consumption, energy_efficiency, e_range, power_consumption.1, age, power_kw, power_hp, fuel_consumption_1, how_many_extras]
# Index: []

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type  doors     warranty   mileage    Gearbox fuel_type  \
# ...

# %%
df1.isnull().sum()
# Out:
# make_model                  0
# make                        0
# location                    0
# price                       0
# body_type                   0
# type                        0
# doors                     332
# warranty                12214
# mileage                     0
# Gearbox                   238
# fuel_type                   0
# seller                      0
# seats                    3003
# engine_size_cc           1024
# gears                    8915
# co_emission              9163
# drivetrain              11074
# cylinders                8956
# comfort_convenience      3059
# entertainment_media      4784
# safety_security          3082
# numbers_extras           4943
# empty_weight            10238
# full_service_history    15242
# non-smoker              16060
# emission_class          10056
# upholstery               9582
# previous_owner          13818
# other_fuel              26307
# power_consumption       26723
# energy_efficiency       19746
# ...

# %%
df1.Gearbox.unique()
# Out:
# array(['Manual', 'Automatic', nan, 'Semi-automatic'], dtype=object)

# %%
#Vehicles with unknown gear may be dropped. Gear selection is important in vehicle prices.
df1.dropna(subset=['Gearbox'], inplace=True)

# %%
numeric_columns = df1.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_columns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type  doors     warranty   mileage    Gearbox fuel_type  \
# ...

# %%
df1=df1.drop('power_consumption.1',axis=1)

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type  doors     warranty   mileage    Gearbox fuel_type  \
# ...

# %%
#Two more columns can be dropped in line with the heatmap correlation 

df1=df1.drop(['seats','doors'],axis=1)

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type     warranty   mileage    Gearbox fuel_type  seller  \
# ...

# %%
df1['seller'].value_counts()
# Out:
# Dealer            24390
# Private seller     2215
# Name: seller, dtype: int64

# %%
#Private seller has no warranty
df1[df1['seller']=='Private seller'].warranty.isnull().sum()
# Out:
# 2215

# %%
df1.loc[df1['seller'] == 'Private seller', 'warranty'] = 0

# %%
df1['warranty'].value_counts()
# Out:
# 12     9024
# yes    2337
#        2103
# 24     1303
# 60      875
#        ...
# 117       1
# 43        1
# 65        1
# 110       1
# 9         1
# Name: warranty, Length: 63, dtype: int64

# %%
df1.loc[df1['warranty'] == 0, 'warranty'] = 'yes'

# %%
df1.loc[df1['warranty'] == 'yes', 'warranty'] = 'No'

# %%
df1['warranty'].value_counts()
# Out:
# 12     9024
# No     2337
#        2103
# 24     1303
# 60      875
#        ...
# 117       1
# 43        1
# 65        1
# 110       1
# 9         1
# Name: warranty, Length: 63, dtype: int64

# %%
df1['warranty']=df1['warranty'].str.strip(' months').str.strip('Ye').str.replace('\n','')

# %%
df1.loc[df1['warranty'] != 'No', 'warranty'] = 'Yes'

# %%
df1['warranty'].value_counts()
# Out:
# Yes    24268
# No      2337
# Name: warranty, dtype: int64

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type warranty   mileage    Gearbox fuel_type  seller  \
# ...

# %%
df1.loc[df1['warranty'] == 'No', 'warranty'] = 0

# %%
df1.loc[df1['warranty'] == 'Yes', 'warranty'] = 1

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type warranty   mileage    Gearbox fuel_type  seller  \
# ...

# %%
df1['warranty']=df1['warranty'].astype(float)

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26838               Volvo S60          Volvo       ES   4999.0     Sedan
# 26839               Volvo S40          Volvo       NL   5499.0     Sedan
# 26840               Volvo C30          Volvo       BE   7300.0     Sedan
# 26841               Volvo S90          Volvo       NL  29900.0     Sedan
# 26842               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type  warranty   mileage    Gearbox fuel_type  seller  \
# ...

# %%
df1[(df1['make_model']=='Volvo XC60')].mean()
# Out:
# price              40021.106529
# warranty               1.000000
# mileage            67412.185567
# engine_size_cc      1974.367491
# gears                  7.547368
# cylinders              4.078125
# empty_weight        1977.860335
# previous_owner         1.201923
# age                    3.680412
# power_kw             176.148276
# power_hp             239.386207
# how_many_extras        6.556391
# dtype: float64

# %%
nan_rows = df1[df1['engine_size_cc'].isnull()]

for index, row in nan_rows.iterrows():
    make_model_value = row['make_model']
    similar_cars = df1[df1['make_model'] == make_model_value]
    mean_engine_size = similar_cars['engine_size_cc'].mean()
    df1.at[index, 'engine_size_cc'] = mean_engine_size

# %%
df1[df1['engine_size_cc'].isnull()]
# Out:
#                    make_model           make location     price  \
# 135       Mercedes-Benz A 140  Mercedes-Benz       FR   15000.0
# 320       Mercedes-Benz Viano  Mercedes-Benz       ES    9300.0
# 600         Mercedes-Benz 190  Mercedes-Benz       DE  180000.0
# 695         Mercedes-Benz 190  Mercedes-Benz       DE  199999.0
# 725      Mercedes-Benz SL 450  Mercedes-Benz       BE   14995.0
# 759         Mercedes-Benz 190  Mercedes-Benz       FR   79340.0
# 1131   Mercedes-Benz E 50 AMG  Mercedes-Benz       ES   63900.0
# 1181        Mercedes-Benz EQA  Mercedes-Benz       BE   58900.0
# 1267    Mercedes-Benz EQB 350  Mercedes-Benz       ES   64900.0
# 1389        Mercedes-Benz EQA  Mercedes-Benz       ES   57200.0
# 1912        Mercedes-Benz EQS  Mercedes-Benz       ES  140000.0
# 1926        Mercedes-Benz EQS  Mercedes-Benz       ES  151369.0
# 1956        Mercedes-Benz 190  Mercedes-Benz       BE   49900.0
# 2053        Mercedes-Benz EQS  Mercedes-Benz       BE  109950.0
# ...

# %%
df1=df1.dropna(subset=['engine_size_cc'])

# %%
df1['engine_size_cc'].isnull().sum()
# Out:
# 0

# %%
df1 = df1.reset_index(drop=True)

# %%
df1.shape[0]
# Out:
# 26557

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26552               Volvo S60          Volvo       ES   4999.0     Sedan
# 26553               Volvo S40          Volvo       NL   5499.0     Sedan
# 26554               Volvo C30          Volvo       BE   7300.0     Sedan
# 26555               Volvo S90          Volvo       NL  29900.0     Sedan
# 26556               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type  warranty   mileage    Gearbox fuel_type  seller  \
# ...

# %%
df1.isnull().sum()
# Out:
# make_model                  0
# make                        0
# location                    0
# price                       0
# body_type                   0
# type                        0
# warranty                    0
# mileage                     0
# Gearbox                     0
# fuel_type                   0
# seller                      0
# engine_size_cc              0
# gears                    8692
# co_emission              9011
# drivetrain              10846
# cylinders                8732
# comfort_convenience      2950
# entertainment_media      4626
# safety_security          2971
# numbers_extras           4814
# empty_weight             9977
# full_service_history    15004
# non-smoker              15843
# emission_class           9821
# upholstery               9418
# previous_owner          13624
# age                         2
# power_kw                  430
# power_hp                  430
# fuel_consumption_1       5032
# how_many_extras          4814
# ...

# %%
nan_rows = df1[df1['gears'].isnull()]

for index, row in nan_rows.iterrows():
    make_model_value = row['make_model']
    gearbox_value = row['Gearbox']
    similar_cars = df1[(df1['make_model'] == make_model_value) & (df1['Gearbox'] == gearbox_value)]
    
    mean_value = similar_cars['gears'].mean()
    df1.loc[index, 'gears'] = mean_value

# %%
df1['gears'].isnull().sum()
# Out:
# 186

# %%
df1=df1.dropna(subset=['gears'])

# %%
df1 = df1.reset_index(drop=True)

# %%
df1.isnull().sum()
# Out:
# make_model                  0
# make                        0
# location                    0
# price                       0
# body_type                   0
# type                        0
# warranty                    0
# mileage                     0
# Gearbox                     0
# fuel_type                   0
# seller                      0
# engine_size_cc              0
# gears                       0
# co_emission              8919
# drivetrain              10711
# cylinders                8584
# comfort_convenience      2895
# entertainment_media      4565
# safety_security          2914
# numbers_extras           4752
# empty_weight             9823
# full_service_history    14879
# non-smoker              15736
# emission_class           9723
# upholstery               9349
# previous_owner          13528
# age                         2
# power_kw                  419
# power_hp                  419
# fuel_consumption_1       4933
# how_many_extras          4752
# ...

# %%
df1[df1['age'].isnull()]
# Out:
#                    make_model           make location     price  \
# 633    Mercedes-Benz E 53 AMG  Mercedes-Benz       BE  108900.0
# 15837          Toyota Corolla         Toyota       NL   33999.0
#
#            body_type             type  warranty  mileage    Gearbox fuel_type  \
# 633     Convertible    Demonstration        1.0   3856.0  Automatic    Diesel
# 15837       Compact    Demonstration        1.0   2494.0  Automatic   Benzine
#
#        seller  engine_size_cc  gears co_emission drivetrain  cylinders  \
# 633    Dealer          2999.0    8.0         219       4WD         NaN
# 15837  Dealer          1987.0    1.0          89        NaN        4.0
#
#                                      comfort_convenience  \
# 633    360° camera, Air conditioning, Automatic clima...
# 15837  Air conditioning, Armrest, Automatic climate c...
#
#                                      entertainment_media  \
# 633    Android Auto, Apple CarPlay, Bluetooth, CD pla...
# ...

# %%
df1[df1['make_model']=='Mercedes-Benz E 53 AMG'].mean()
# Out:
# price              83046.869565
# warranty               1.000000
# mileage            29713.739130
# engine_size_cc      2999.000000
# gears                  8.857143
# cylinders              6.000000
# empty_weight        1993.153846
# previous_owner         1.125000
# age                    1.695652
# power_kw             320.695652
# power_hp             435.956522
# how_many_extras        9.590909
# dtype: float64

# %%
df1.iloc[633,26]=2.0

# %%
df1.iloc[633,26]
# Out:
# 2.0

# %%
df1
# Out:
#                    make_model           make location    price  body_type  \
# 0         Mercedes-Benz A 160  Mercedes-Benz       ES  16950.0   Compact
# 1       Mercedes-Benz EQE 350  Mercedes-Benz       ES  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz       ES  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz       ES  16800.0   Compact
# ...                       ...            ...      ...      ...        ...
# 26366               Volvo S60          Volvo       ES   4999.0     Sedan
# 26367               Volvo S40          Volvo       NL   5499.0     Sedan
# 26368               Volvo C30          Volvo       BE   7300.0     Sedan
# 26369               Volvo S90          Volvo       NL  29900.0     Sedan
# 26370               Volvo S80          Volvo       NL   4440.0     Sedan
#
#                    type  warranty   mileage    Gearbox fuel_type  seller  \
# ...

# %%
df1[df1['age'].isnull()]
# Out:
#            make_model    make location    price  body_type             type  \
# 15837  Toyota Corolla  Toyota       NL  33999.0   Compact    Demonstration
#
#        warranty  mileage    Gearbox fuel_type  seller  engine_size_cc  gears  \
# 15837       1.0   2494.0  Automatic   Benzine  Dealer          1987.0    1.0
#
#       co_emission drivetrain  cylinders  \
# 15837          89        NaN        4.0
#
#                                      comfort_convenience  \
# 15837  Air conditioning, Armrest, Automatic climate c...
#
#                                      entertainment_media  \
# 15837  Android Auto, Apple CarPlay, Bluetooth, Digita...
#
#                                          safety_security  \
# 15837  ABS, Daytime running lights, Distance warning ...
#
#                                           numbers_extras  empty_weight  \
# 15837  Alloy wheels, Automatically dimming interior m...        1315.0
#
# ...

# %%
df1=df1.dropna(subset=['age'])

# %%
df1[df1['age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [make_model, make, location, price, body_type, type, warranty, mileage, Gearbox, fuel_type, seller, engine_size_cc, gears, co_emission, drivetrain, cylinders, comfort_convenience, entertainment_media, safety_security, numbers_extras, empty_weight, full_service_history, non-smoker, emission_class, upholstery, previous_owner, age, power_kw, power_hp, fuel_consumption_1, how_many_extras]
# Index: []

# %%
df1.isnull().sum()
# Out:
# make_model                  0
# make                        0
# location                    0
# price                       0
# body_type                   0
# type                        0
# warranty                    0
# mileage                     0
# Gearbox                     0
# fuel_type                   0
# seller                      0
# engine_size_cc              0
# gears                       0
# co_emission              8919
# drivetrain              10710
# cylinders                8584
# comfort_convenience      2895
# entertainment_media      4565
# safety_security          2914
# numbers_extras           4752
# empty_weight             9823
# full_service_history    14879
# non-smoker              15735
# emission_class           9723
# upholstery               9349
# previous_owner          13527
# age                         0
# power_kw                  419
# power_hp                  419
# fuel_consumption_1       4932
# how_many_extras          4752
# ...

# %%
df1['non-smoker'].isnull().sum()
# Out:
# 15735

# %%
df1['non-smoker'].fillna('No', inplace=True)

# %%
df1['non-smoker'].isnull().sum()
# Out:
# 0

# %%
df1.groupby('previous_owner')['age'].mean()
# Out:
# previous_owner
# 0.0    23.500000
# 1.0     4.034030
# 2.0     8.828525
# 3.0    14.218236
# 4.0    16.676136
# 5.0    16.878788
# 6.0    17.083333
# 7.0    18.545455
# 8.0    17.187500
# 9.0    19.142857
# Name: age, dtype: float64

# %%
df1['previous_owner'].isnull().sum()
# Out:
# 13527

# %%
owner_age_means = df1.groupby('previous_owner')['age'].mean()

# %%
nan_rows = df1[df1['previous_owner'].isnull()]

# %%
for index, row in nan_rows.iterrows():
    mean_previous_owners = df1[df1['age'] == row['age']]['previous_owner'].mean()
    df1.at[index, 'previous_owner'] = mean_previous_owners

# %%
df1['previous_owner'].isnull().sum()
# Out:
# 17

# %%
df1['previous_owner'].value_counts()
# Out:
# 1.000000    8760
# 2.000000    3126
# 1.437500    1375
# 1.256318    1089
# 1.323282    1011
#             ...
# 1.037765       1
# 1.830676       1
# 1.178257       1
# 1.184031       1
# 1.958333       1
# Name: previous_owner, Length: 136, dtype: int64
